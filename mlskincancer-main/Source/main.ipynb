# %% [markdown]
# # 1 Load the required modules

# %%
## WARNING: Use tensorflow version >= 2.x.x
# Basic libraries
import numpy as np
# Neural network's components
from keras.preprocessing.image import ImageDataGenerator # Used to stream images
import keras
from tensorflow.keras.models import Sequential, Model # Basic commands for neural networks building
from tensorflow.keras.layers import Dense, Dropout, Flatten # Neurons layers
from tensorflow.keras.layers import Conv2D, MaxPool2D # Convolutional layers
from tensorflow.keras import backend as K # Keras backed to de-allocate memory
from tensorflow.keras.optimizers import Adam # Optimizer for neural networks
import matplotlib.pyplot as plt

# Configurations
# %run my_utils.ipynb
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2 MultiLayer Perceptron Neural Network

# %%
def build_mlp(neurons=[64, 64, 128], num_classes=2, lr=1e-5, input_shape=(256, 256, 3)):
    model = Sequential()
    
    # Input layer
    model.add(Flatten(input_shape = input_shape))
    
    # for each of the next hidden layers
    for layer_neurons in neurons:
        model.add(Dense(layer_neurons, activation = 'relu'))
        model.add(Dropout(0.5))
    
    # output layer
    model.add(Dense(num_classes, activation='softmax'))
    
    # Add the optimizer
    optimizer = Adam(lr = lr)
    model.compile(optimizer = optimizer, loss = "binary_crossentropy", metrics = ["accuracy"])
    
    return model

# %% [markdown]
# # 3 Convolutional Neural Network

# %%
def build_cnn(input_shape=(244, 244, 3), num_classes=2, lr=1e-5, filters=[64, 64], neurons=[128]):
    
    model = Sequential()
    
    # First convolutional layer
    # filters[0]=64 filters used for the convolutions
    # "Kernel size" is filter's size which is chosen to be 5x5
    # "padding='Same'" means that in case that an image is not of given dimensions
    #                  it is filled with its outer pixels until it will
    #                  be of given dimensions
    # "input_shape" of the input layer is the images' dimensions
    # "activation='relu'" is the function max(0, x)
    model.add(Conv2D(filters[0], kernel_size = (5,5),\
                     padding = 'Same', input_shape = input_shape,\
                     activation = 'relu'))
    # Command below checks the 5 neighbor pixels of the pixel we examine
    # this meaning it checks the upper, lower, left and right pixels
    model.add(MaxPool2D(pool_size = (5,5)))
    # Command below drops the 25% of the information that is produced
    # on this layer, to avoid over-fitting
    model.add(Dropout(0.25))
    
    # Second and later convolutional layers
    for i in range(2, len(filters)+1):
        model.add(Conv2D(filters[i-1], kernel_size=(5,5),\
                         padding = 'Same', activation = 'relu'))
        model.add(MaxPool2D(pool_size = (5,5)))
        model.add(Dropout(0.25))
    
    # The model so far outputs 3D feature maps (height, width, features)
    
    # An MLP to produce the output
    model.add(Flatten()) # this converts our 3D feature maps to 1D feature vectors
    for layer_neurons in neurons:
        model.add(Dense(layer_neurons, activation = 'relu'))
    model.add(Dense(num_classes, activation = 'softmax'))
    
    model.summary()
    
    optimizer = Adam(lr = lr)
    
    model.compile(optimizer = optimizer, loss = "binary_crossentropy", metrics = ["accuracy"])
    
    return model

# %% [markdown]
# # 4 Run the models

# %%
if __name__ == '__main__':    
    if int(tf_version().split('.')[0]) < 2:
        raise Exception('Tensorflow version must be at least 2.x.x! Please update!')

    batch_size = 64 # Amount of elements that feeded together to the model for processing
    rescale_factor = 1./255
    lr = 1e-5 # Initial learning rate
    num_classes = 2 # Number of classes to classify to
    y_actual, _ = y_actual_labels() # Get the actual label for the test set

    #menu for running the models, initializing the number of epochs
    choice = -1
    while choice != 0:
        choice = int(input('\nInsert:'                           '\n\t1 - To evaluate a MultiLayer Perceptron NN'                           '\n\t2 - To evaluate a Convolutional NN'                           '\n\t3 - To evaluate a Stochastic Gradient Descent'                '\n\t4 - To evaluate a Support Vector Machine'                  '\n\t0 - To Exit'                           '\nChoice: '))

        epochs = 1
        name = ''

        if choice == 0:
            raise SystemExit()
        elif choice == 1:
            model = build_mlp(neurons = [512, 512], num_classes = num_classes, lr = lr)
            epochs = 200
            name = 'MLP'
        elif choice == 2:
            model = build_cnn(input_shape = (256, 256, 3), num_classes = num_classes,
                              lr = lr, filters = [32, 32, 32], neurons = [512])
            epochs = 200
            name = 'CNN'
        elif choice == 3:
            epochs = 5
            name = 'SGD'
        elif choice == 4:
            epochs = 5
            name = 'SVM'
        else:
            print('Invalid choice!\n')
            continue
            
        if choice in [1, 2]:
            result = run_nn(model, epochs = epochs, batch_size = batch_size, rescale_factor = rescale_factor, name = name)

            print(name + ' model evaluated in train set with',
                  ' and '.join([i + ' = ' + str(j) for i, j in result['metrics'].items()]))
            #print accuracy-loss plot
            for what in ['accuracy', 'loss']:
                where = 'lower right'

                if what == 'loss':
                    where = 'lower left'

                plot_model(result['history'].history[what], result['history'].history['val_' + what],
                                 what, where)
                
                

            
        elif choice in [3, 4]:
            
            result = run_not_nn(epochs = epochs, batch_size = batch_size, alpha = lr, rescale_factor = rescale_factor, name = name)
            
            get_ipython().run_line_magic('matplotlib', 'inline')
            import matplotlib.pyplot as plt
           
            plt.plot([x+1 for x in range(epochs)], result['history'])
            plt.title(name+ ' model accuracy')
            
            plt.ylabel('accuracy')
            plt.xlabel('epoch')
            plt.legend(['validation'], loc='lower left')
            plt.show()
            
            
        #print confusion matrix
        print('\n')
        print(confusion_matrix(y_actual, result['predictions']))

        #print classification metrics 
        print('\n')
        print(classification_report(y_actual, result['predictions']))
# Out:
# Insert:
# 	1 - To evaluate a MultiLayer Perceptron NN
# 	2 - To evaluate a Convolutional NN
# 	3 - To evaluate a Stochastic Gradient Descent
# 	4 - To evaluate a Support Vector Machine
# 	0 - To Exit
# Choice: 1
# Found 9233 images belonging to 2 classes.
# Found 1283 images belonging to 2 classes.
# Start training process for the MLP model...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 144 steps, validate for 20 steps
# Epoch 1/200
# 144/144 [==============================] - 202s 1s/step - loss: 0.8036 - accuracy: 0.5384 - val_loss: 0.6659 - val_accuracy: 0.5719
# Epoch 2/200
# 144/144 [==============================] - 153s 1s/step - loss: 0.6520 - accuracy: 0.5867 - val_loss: 0.6332 - val_accuracy: 0.5703
# Epoch 3/200
# 144/144 [==============================] - 174s 1s/step - loss: 0.6395 - accuracy: 0.6053 - val_loss: 0.6159 - val_accuracy: 0.6602
# Epoch 4/200
# 144/144 [==============================] - 201s 1s/step - loss: 0.6249 - accuracy: 0.6489 - val_loss: 0.6002 - val_accuracy: 0.6672
# Epoch 5/200
# 144/144 [==============================] - 203s 1s/step - loss: 0.6150 - accuracy: 0.6605 - val_loss: 0.5949 - val_accuracy: 0.7016
# Epoch 6/200
# 144/144 [==============================] - 189s 1s/step - loss: 0.6060 - accuracy: 0.6657 - val_loss: 0.5954 - val_accuracy: 0.7109
# Epoch 7/200
# 144/144 [==============================] - 222s 2s/step - loss: 0.6013 - accuracy: 0.6776 - val_loss: 0.5739 - val_accuracy: 0.6820
# Epoch 8/200
# 144/144 [==============================] - 225s 2s/step - loss: 0.5926 - accuracy: 0.6806 - val_loss: 0.5710 - val_accuracy: 0.6953
# Epoch 9/200
# 144/144 [==============================] - 213s 1s/step - loss: 0.5932 - accuracy: 0.6772 - val_loss: 0.5706 - val_accuracy: 0.7172
# Epoch 10/200
# 144/144 [==============================] - 275s 2s/step - loss: 0.5892 - accuracy: 0.6895 - val_loss: 0.5579 - val_accuracy: 0.6945
# Epoch 11/200
# 144/144 [==============================] - 197s 1s/step - loss: 0.5869 - accuracy: 0.6848 - val_loss: 0.5540 - val_accuracy: 0.7133
# Epoch 12/200
# 144/144 [==============================] - 187s 1s/step - loss: 0.5795 - accuracy: 0.7002 - val_loss: 0.5669 - val_accuracy: 0.7375
# Epoch 13/200
# 144/144 [==============================] - 231s 2s/step - loss: 0.5767 - accuracy: 0.6994 - val_loss: 0.5489 - val_accuracy: 0.7102
# Epoch 14/200
# 144/144 [==============================] - 267s 2s/step - loss: 0.5753 - accuracy: 0.6995 - val_loss: 0.5498 - val_accuracy: 0.7203
# Epoch 15/200
# 144/144 [==============================] - 210s 1s/step - loss: 0.5684 - accuracy: 0.7051 - val_loss: 0.5435 - val_accuracy: 0.7125
# Epoch 16/200
# 144/144 [==============================] - 207s 1s/step - loss: 0.5676 - accuracy: 0.7059 - val_loss: 0.5480 - val_accuracy: 0.7258
# Epoch 17/200
# 144/144 [==============================] - 256s 2s/step - loss: 0.5762 - accuracy: 0.6933 - val_loss: 0.5451 - val_accuracy: 0.7219
# Epoch 18/200
# 144/144 [==============================] - 307s 2s/step - loss: 0.5795 - accuracy: 0.6807 - val_loss: 0.5643 - val_accuracy: 0.7359
# MLP model training process was successful!
# Start evaluating the MLP model over validation set...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 20/20 [==============================] - 15s 766ms/step - loss: 0.5643 - accuracy: 0.7359
# MLP model was evaluated on validation set successfully!
# Start evaluating the MLP model on test set...
# Found 2671 images belonging to 1 classes.
# 2671/2671 [==============================] - 350s 131ms/step
# MLP model was evaluated on test set successfully!
# MLP model evaluated in train set with loss = 0.5643392220139504 and accuracy = 0.7359375
#                      true_benign  true_malignant
# predicted_benign             987             157
# predicted_malignant          505            1022
#
#
#              precision    recall  f1-score support
# benign        0.862762  0.661528  0.748862    1492
# malignant     0.669286  0.866836  0.755358    1179
# accuracy            NA        NA  0.752153    2671
# macro avg     0.766024  0.764182   0.75211    2671
# weighted avg   0.77736  0.752153   0.75173    2671
#
# Insert:
# 	1 - To evaluate a MultiLayer Perceptron NN
# 	2 - To evaluate a Convolutional NN
# 	3 - To evaluate a Stochastic Gradient Descent
# 	4 - To evaluate a Support Vector Machine
# 	0 - To Exit
# Choice: 2
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 51, 51, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 51, 51, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 51, 51, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 120,770
# Trainable params: 120,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 9233 images belonging to 2 classes.
# Found 1283 images belonging to 2 classes.
# Start training process for the CNN model...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 144 steps, validate for 20 steps
# Epoch 1/200
# 144/144 [==============================] - 1192s 8s/step - loss: 0.6996 - accuracy: 0.5160 - val_loss: 0.6938 - val_accuracy: 0.4477
# Epoch 2/200
# 144/144 [==============================] - 1032s 7s/step - loss: 0.6922 - accuracy: 0.5348 - val_loss: 0.6897 - val_accuracy: 0.6195
# Epoch 3/200
# 144/144 [==============================] - 1016s 7s/step - loss: 0.6882 - accuracy: 0.5464 - val_loss: 0.6871 - val_accuracy: 0.6602
# Epoch 4/200
# 144/144 [==============================] - 818s 6s/step - loss: 0.6785 - accuracy: 0.5736 - val_loss: 0.6819 - val_accuracy: 0.6539
# Epoch 5/200
# 144/144 [==============================] - 809s 6s/step - loss: 0.6681 - accuracy: 0.5906 - val_loss: 0.6739 - val_accuracy: 0.6430
# Epoch 6/200
# 144/144 [==============================] - 801s 6s/step - loss: 0.6453 - accuracy: 0.6205 - val_loss: 0.6586 - val_accuracy: 0.6883
# Epoch 7/200
# 144/144 [==============================] - 819s 6s/step - loss: 0.6129 - accuracy: 0.6680 - val_loss: 0.6329 - val_accuracy: 0.6570
# Epoch 8/200
# 144/144 [==============================] - 809s 6s/step - loss: 0.5787 - accuracy: 0.6905 - val_loss: 0.6082 - val_accuracy: 0.6844
# Epoch 9/200
# 144/144 [==============================] - 806s 6s/step - loss: 0.5506 - accuracy: 0.7150 - val_loss: 0.5860 - val_accuracy: 0.7039
# Epoch 10/200
# 144/144 [==============================] - 800s 6s/step - loss: 0.5267 - accuracy: 0.7270 - val_loss: 0.5683 - val_accuracy: 0.6977
# Epoch 11/200
# 144/144 [==============================] - 720s 5s/step - loss: 0.5081 - accuracy: 0.7386 - val_loss: 0.5477 - val_accuracy: 0.7219
# Epoch 12/200
# 144/144 [==============================] - 675s 5s/step - loss: 0.4976 - accuracy: 0.7458 - val_loss: 0.5353 - val_accuracy: 0.7156
# Epoch 13/200
# 144/144 [==============================] - 1017s 7s/step - loss: 0.4881 - accuracy: 0.7562 - val_loss: 0.5250 - val_accuracy: 0.7375
# Epoch 14/200
# 144/144 [==============================] - 952s 7s/step - loss: 0.4766 - accuracy: 0.7632 - val_loss: 0.5154 - val_accuracy: 0.7414
# Epoch 15/200
# 144/144 [==============================] - 756s 5s/step - loss: 0.4725 - accuracy: 0.7640 - val_loss: 0.5097 - val_accuracy: 0.7633
# Epoch 16/200
# 144/144 [==============================] - 814s 6s/step - loss: 0.4659 - accuracy: 0.7697 - val_loss: 0.5046 - val_accuracy: 0.7547
# Epoch 17/200
# 144/144 [==============================] - 851s 6s/step - loss: 0.4636 - accuracy: 0.7688 - val_loss: 0.5016 - val_accuracy: 0.7672
# Epoch 18/200
# 144/144 [==============================] - 917s 6s/step - loss: 0.4609 - accuracy: 0.7690 - val_loss: 0.4990 - val_accuracy: 0.7680
# Epoch 19/200
# 144/144 [==============================] - 1122s 8s/step - loss: 0.4567 - accuracy: 0.7738 - val_loss: 0.5007 - val_accuracy: 0.7766
# Epoch 20/200
# 144/144 [==============================] - 1236s 9s/step - loss: 0.4541 - accuracy: 0.7760 - val_loss: 0.4965 - val_accuracy: 0.7758
# Epoch 21/200
# 144/144 [==============================] - 1128s 8s/step - loss: 0.4510 - accuracy: 0.7754 - val_loss: 0.4979 - val_accuracy: 0.7789
# Epoch 22/200
# 144/144 [==============================] - 1048s 7s/step - loss: 0.4504 - accuracy: 0.7740 - val_loss: 0.4898 - val_accuracy: 0.7703
# Epoch 23/200
# 144/144 [==============================] - 1125s 8s/step - loss: 0.4418 - accuracy: 0.7778 - val_loss: 0.4895 - val_accuracy: 0.7750
# Epoch 24/200
# 144/144 [==============================] - 1001s 7s/step - loss: 0.4414 - accuracy: 0.7769 - val_loss: 0.4907 - val_accuracy: 0.7781
# Epoch 25/200
# 144/144 [==============================] - 814s 6s/step - loss: 0.4401 - accuracy: 0.7787 - val_loss: 0.4862 - val_accuracy: 0.7789
# Epoch 26/200
# 144/144 [==============================] - 798s 6s/step - loss: 0.4373 - accuracy: 0.7777 - val_loss: 0.4837 - val_accuracy: 0.7781
# Epoch 27/200
# 144/144 [==============================] - 973s 7s/step - loss: 0.4366 - accuracy: 0.7815 - val_loss: 0.4916 - val_accuracy: 0.7727
# Epoch 28/200
# 144/144 [==============================] - 500s 3s/step - loss: 0.4353 - accuracy: 0.7807 - val_loss: 0.4823 - val_accuracy: 0.7750
# Epoch 29/200
# 144/144 [==============================] - 526s 4s/step - loss: 0.4334 - accuracy: 0.7801 - val_loss: 0.4799 - val_accuracy: 0.7781
# Epoch 30/200
# 144/144 [==============================] - 627s 4s/step - loss: 0.4295 - accuracy: 0.7847 - val_loss: 0.4739 - val_accuracy: 0.7758
# Epoch 31/200
# 144/144 [==============================] - 688s 5s/step - loss: 0.4288 - accuracy: 0.7849 - val_loss: 0.4859 - val_accuracy: 0.7703
# Epoch 32/200
# 144/144 [==============================] - 587s 4s/step - loss: 0.4256 - accuracy: 0.7877 - val_loss: 0.4750 - val_accuracy: 0.7727
# Epoch 33/200
# 144/144 [==============================] - 638s 4s/step - loss: 0.4253 - accuracy: 0.7849 - val_loss: 0.4720 - val_accuracy: 0.7727
# Epoch 34/200
# 144/144 [==============================] - 578s 4s/step - loss: 0.4240 - accuracy: 0.7871 - val_loss: 0.4702 - val_accuracy: 0.7727
# Epoch 35/200
# 144/144 [==============================] - 642s 4s/step - loss: 0.4228 - accuracy: 0.7883 - val_loss: 0.4696 - val_accuracy: 0.7734
# Epoch 36/200
# 144/144 [==============================] - 894s 6s/step - loss: 0.4211 - accuracy: 0.7846 - val_loss: 0.4716 - val_accuracy: 0.7727
# Epoch 37/200
# 144/144 [==============================] - 1022s 7s/step - loss: 0.4207 - accuracy: 0.7904 - val_loss: 0.4630 - val_accuracy: 0.7727
# Epoch 38/200
# 144/144 [==============================] - 995s 7s/step - loss: 0.4213 - accuracy: 0.7893 - val_loss: 0.4747 - val_accuracy: 0.7719
# Epoch 39/200
# 144/144 [==============================] - 977s 7s/step - loss: 0.4195 - accuracy: 0.7885 - val_loss: 0.4712 - val_accuracy: 0.7727
# Epoch 40/200
# 144/144 [==============================] - 960s 7s/step - loss: 0.4180 - accuracy: 0.7898 - val_loss: 0.4735 - val_accuracy: 0.7703
# CNN model training process was successful!
# Start evaluating the CNN model over validation set...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 20/20 [==============================] - 38s 2s/step - loss: 0.4735 - accuracy: 0.7703
# CNN model was evaluated on validation set successfully!
# Start evaluating the CNN model on test set...
# Found 2671 images belonging to 1 classes.
# 2671/2671 [==============================] - 92s 34ms/step
# CNN model was evaluated on test set successfully!
# Saved model to disk
# CNN model evaluated in train set with loss = 0.47346153259277346 and accuracy = 0.7703125
#                      true_benign  true_malignant
# predicted_benign             987              66
# predicted_malignant          505            1113
#
#
#              precision    recall  f1-score support
# benign        0.937322  0.661528  0.775639    1492
# malignant     0.687886   0.94402  0.795853    1179
# accuracy            NA        NA  0.786222    2671
# macro avg     0.812604  0.802774  0.785746    2671
# weighted avg  0.827219  0.786222  0.784561    2671
#
# Insert:
# 	1 - To evaluate a MultiLayer Perceptron NN
# 	2 - To evaluate a Convolutional NN
# 	3 - To evaluate a Stochastic Gradient Descent
# 	4 - To evaluate a Support Vector Machine
# 	0 - To Exit
# Choice: 3
# Found 9233 images belonging to 2 classes.
# Found 1283 images belonging to 2 classes.
# Start training process for the SGD model...
# Epoch 1/5 (254.55 seconds)
# Epoch 2/5 (230.58 seconds)
# Epoch 3/5 (250.93 seconds)
# Epoch 4/5 (243.47 seconds)
# Epoch 5/5 (236.29 seconds)
# Training process for the SGD model was sucessful!
# Start evaluating the SGD model on test set...
# Found 2671 images belonging to 1 classes.
# 1000 images processed
# 2000 images processed
# 2671 images processed
# SGD model was evaluated on test set successfully!
#                      true_benign  true_malignant
# predicted_benign            1432            1069
# predicted_malignant           60             110
#
#
#              precision     recall  f1-score support
# benign        0.572571   0.959786  0.717255    1492
# malignant     0.647059  0.0932994  0.163084    1179
# accuracy            NA         NA  0.577312    2671
# macro avg     0.609815   0.526542  0.440169    2671
# weighted avg   0.60545   0.577312   0.47264    2671
#
# Insert:
# 	1 - To evaluate a MultiLayer Perceptron NN
# 	2 - To evaluate a Convolutional NN
# 	3 - To evaluate a Stochastic Gradient Descent
# 	4 - To evaluate a Support Vector Machine
# 	0 - To Exit
# Choice: 4
# Found 9233 images belonging to 2 classes.
# Found 1283 images belonging to 2 classes.
# Start training process for the SVM model...
# Epoch 1/5 (963.83 seconds)
# Epoch 2/5 (870.30 seconds)
# Epoch 3/5 (718.69 seconds)
# Epoch 4/5 (268.09 seconds)
# Epoch 5/5 (221.88 seconds)
# Training process for the SVM model was sucessful!
# Start evaluating the SVM model on test set...
# Found 2671 images belonging to 1 classes.
# 1000 images processed
# 2000 images processed
# 2671 images processed
# SVM model was evaluated on test set successfully!
#                      true_benign  true_malignant
# predicted_benign             663             122
# predicted_malignant          829            1057
#
#
#              precision    recall  f1-score support
# benign        0.844586   0.44437  0.582345    1492
# malignant     0.560445  0.896522  0.689723    1179
# accuracy            NA        NA  0.643954    2671
# macro avg     0.702516  0.670446  0.636034    2671
# weighted avg  0.719164  0.643954  0.629742    2671
#
# Insert:
# 	1 - To evaluate a MultiLayer Perceptron NN
# 	2 - To evaluate a Convolutional NN
# 	3 - To evaluate a Stochastic Gradient Descent
# 	4 - To evaluate a Support Vector Machine
# 	0 - To Exit
# Choice: 0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# D:\Users\astar\anaconda3\envs\t\lib\site-packages\IPython\core\interactiveshell.py:3425: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
